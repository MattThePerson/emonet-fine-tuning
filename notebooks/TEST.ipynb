# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
import torch

# %%
a = np.array([1, 0, 2, 1, 2, 3, 2, 0])
b = np.array([1, 1, 0, 1, 2, 3, 2, 1])
confusion_matrix(a, b)
# Out:
# array([[0, 2, 0, 0],
#        [0, 2, 0, 0],
#        [1, 0, 2, 0],
#        [0, 0, 0, 1]])

# %%
rep = classification_report(a, b)
print(rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.50      1.00      0.67         2
#            2       1.00      0.67      0.80         3
#            3       1.00      1.00      1.00         1
#
#     accuracy                           0.62         8
#    macro avg       0.62      0.67      0.62         8
# weighted avg       0.62      0.62      0.59         8

# %%
cm = [[  96,   68,   25,   22,    6,    6,   13,   31],
    [   4, 1355,    6,   13,    1,   14,    0,   27],
    [  17,   47,  317,    8,   19,   21,   19,   12],
    [  20,  115,   11,  521,   50,   14,   15,   13],
    [   5,   20,   25,   64,  433,   26,   22,    1],
    [   5,  115,   22,   15,   15,  442,   32,   10],
    [   9,   19,   31,    5,   11,   64,  433,   27],
    [  13,  211,    9,   16,    1,   16,   11,  359]]

np.trace(cm) / np.sum(cm)

np.diag(cm)
np.diag(cm) / np.sum(cm, axis=1)
# Out:
# array([0.35955056, 0.95422535, 0.68913043, 0.68642951, 0.72651007,
#        0.67378049, 0.72287145, 0.56446541])
